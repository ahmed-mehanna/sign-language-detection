# %% [markdown]
# # 1 - install dependencies

# %%
import numpy as np
import cv2 
import os
import mediapipe as mp
import tensorflow as tf 
from tensorflow import keras
import matplotlib.pyplot as plt
import time
import pandas as pd

# %% [markdown]
# # 2 - keypoints extractions and drawing

# %%
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

num_hand_marks = 21
num_pose_marks = 33


# holistic model process image and return the results as keypoints
def mediapipe_detection(image,model):
    image  = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image  = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    return image,results
    
def draw_styled_landmarks(image,results):
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             ) 
    

# read the keypoints and extract them and process them
def extract_keypoints(results):
    # extract pose marks
    if results.pose_landmarks:
        pose = np.array([ [res.x,res.y,res.z,res.visibility] for res in results.pose_landmarks.landmark ]).flatten()
    else:
        pose = np.zeros(num_pose_marks*4)
    
    # extract left hand
    if results.left_hand_landmarks:
        left_hand = np.array([ [res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark ]).flatten()
    else:
        left_hand = np.zeros(num_hand_marks*3)
        
        
    # extract right hand
    if results.right_hand_landmarks:
        right_hand = np.array([ [res.x,res.y,res.z] for res in results.right_hand_landmarks.landmark ]).flatten()
    else:
        right_hand = np.zeros(num_hand_marks*3)
    
    return np.concatenate([pose,left_hand,right_hand])

# %% [markdown]
# # 3 - read and process data

# %% [markdown]
# ### 3.1 collect data that in classes 0,1,2,3,4, and available in the data/train directory

# %%
data_path = "../../data"
    
data_train_path = os.path.join(data_path,"my_data")

actions = list(os.listdir(data_train_path))
n_actions = len(actions)
dic={}
counter=0
for action in actions:
    dic[action] = counter
    counter+=1

# %%
x=[]
y=[]
for action in actions:
    videos = os.listdir(os.path.join(data_train_path,action))
    for video in videos:
        x.append(os.path.join(data_train_path,action,video))
        y.append(dic[action])

train = x
labels = y

# %%
print(len(x),len(y))
# Out:
# 250 250

# %% [markdown]
# ### 3.2 process videos into frames and label to cateogries

# %%
def capture_frames(video_path):
    video = cv2.VideoCapture(video_path)
    video_length = int(video.get(cv2.CAP_PROP_FRAME_COUNT)) - 1
    # count = 0
    # frame_rate = video.get(cv2.CAP_PROP_FRAME_COUNT)

    count=0
    frames = []
    while video.isOpened():
      # frame_id = video.get(0)
        ret, frame = video.read()
        
        if not ret:
            continue
        frames.append(frame)
        count += 1
        # If there are no more frames left
        if (count > (video_length-1)):
          # Release the feed
          video.release()
        # if frame_id % math.floor(1) == 0:
        #     file_name = f"{video_path}_frame_{count}.jpg"
        #     count += 1
        #     # print(f"File name: {file_name}")
        #     frames.append(frame)
        #     # cv2.imwrite(file_name, frame)
    video.release()
    return np.array(frames)


def get_frames(video_path,num_frames):
    frames = capture_frames(video_path)
    video_length = len(frames)
    steps = video_length/num_frames
    count=0
    new_frames=[]
    while count<video_length:
        frame = frames[int(count)]
#         frame = cv2.resize(frame, (256, 256))
#         frame =  (frame/255.0).astype(np.float16)
        new_frames.append(frame)
        count+=steps

    s = np.array(new_frames[:num_frames])
    print("SHAPE",s.shape)
    return np.array(new_frames[:num_frames])

# %%
def extract_keypoints_video(path,i=-1):
    if(i):
        print(i,end="\t")
    frames = get_frames(path,20)
    output_key_points=[]
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        for frame in frames:
            image, results = mediapipe_detection(frame, holistic)
            output_key_points.append(extract_keypoints(results))
    return np.array(output_key_points)

# %% [markdown]
# ### 3.3 - extract the keypoints and save them in train

# %%
if "extracted_features.npy" in os.listdir():
    train = np.load("extracted_features.npy")
else:
    train = np.array([extract_keypoints_video(path,f'iteration : {i+1}/{len(x)}') for i,path in enumerate(x) ])
    np.save('extracted_features.npy', train)
# Out:
# iteration : 1/250	SHAPE (20, 480, 640, 3)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# iteration : 2/250	SHAPE (20, 480, 640, 3)
# iteration : 3/250	SHAPE (20, 480, 640, 3)
# iteration : 4/250	SHAPE (20, 480, 640, 3)
# iteration : 5/250	SHAPE (20, 480, 640, 3)
# iteration : 6/250	SHAPE (20, 480, 640, 3)
# iteration : 7/250	SHAPE (20, 480, 640, 3)
# iteration : 8/250	SHAPE (20, 480, 640, 3)
# iteration : 9/250	SHAPE (20, 480, 640, 3)
# iteration : 10/250	SHAPE (20, 480, 640, 3)
# iteration : 11/250	SHAPE (20, 480, 640, 3)
# iteration : 12/250	SHAPE (20, 480, 640, 3)
# iteration : 13/250	SHAPE (20, 480, 640, 3)
# iteration : 14/250	SHAPE (20, 480, 640, 3)
# iteration : 15/250	SHAPE (20, 480, 640, 3)
# iteration : 16/250	SHAPE (20, 480, 640, 3)
# iteration : 17/250	SHAPE (20, 480, 640, 3)
# iteration : 18/250	SHAPE (20, 480, 640, 3)
# iteration : 19/250	SHAPE (20, 480, 640, 3)
# iteration : 20/250	SHAPE (20, 480, 640, 3)
# iteration : 21/250	SHAPE (20, 480, 640, 3)
# iteration : 22/250	SHAPE (20, 480, 640, 3)
# iteration : 23/250	SHAPE (20, 480, 640, 3)
# iteration : 24/250	SHAPE (20, 480, 640, 3)
# iteration : 25/250	SHAPE (20, 480, 640, 3)
# iteration : 26/250	SHAPE (20, 480, 640, 3)
# iteration : 27/250	SHAPE (20, 480, 640, 3)
# iteration : 28/250	SHAPE (20, 480, 640, 3)
# iteration : 29/250	SHAPE (20, 480, 640, 3)
# iteration : 30/250	SHAPE (20, 480, 640, 3)
# iteration : 31/250	SHAPE (20, 480, 640, 3)
# iteration : 32/250	SHAPE (20, 480, 640, 3)
# iteration : 33/250	SHAPE (20, 480, 640, 3)
# iteration : 34/250	SHAPE (20, 480, 640, 3)
# iteration : 35/250	SHAPE (20, 480, 640, 3)
# iteration : 36/250	SHAPE (20, 480, 640, 3)
# iteration : 37/250	SHAPE (20, 480, 640, 3)
# iteration : 38/250	SHAPE (20, 480, 640, 3)
# iteration : 39/250	SHAPE (20, 480, 640, 3)
# iteration : 40/250	SHAPE (20, 480, 640, 3)
# iteration : 41/250	SHAPE (20, 480, 640, 3)
# iteration : 42/250	SHAPE (20, 480, 640, 3)
# iteration : 43/250	SHAPE (20, 480, 640, 3)
# iteration : 44/250	SHAPE (20, 480, 640, 3)
# iteration : 45/250	SHAPE (20, 480, 640, 3)
# iteration : 46/250	SHAPE (20, 480, 640, 3)
# iteration : 47/250	SHAPE (20, 480, 640, 3)
# iteration : 48/250	SHAPE (20, 480, 640, 3)
# iteration : 49/250	SHAPE (20, 480, 640, 3)
# iteration : 50/250	SHAPE (20, 480, 640, 3)
# iteration : 51/250	SHAPE (20, 480, 640, 3)
# iteration : 52/250	SHAPE (20, 480, 640, 3)
# iteration : 218/250	SHAPE (20, 480, 640, 3)
# iteration : 219/250	SHAPE (20, 480, 640, 3)
# iteration : 220/250	SHAPE (20, 480, 640, 3)
# iteration : 221/250	SHAPE (20, 480, 640, 3)
# iteration : 222/250	SHAPE (20, 480, 640, 3)
# iteration : 223/250	SHAPE (20, 480, 640, 3)
# iteration : 224/250	SHAPE (20, 480, 640, 3)
# iteration : 225/250	SHAPE (20, 480, 640, 3)
# iteration : 226/250	SHAPE (20, 480, 640, 3)
# iteration : 227/250	SHAPE (20, 480, 640, 3)
# iteration : 228/250	SHAPE (20, 480, 640, 3)
# iteration : 229/250	SHAPE (20, 480, 640, 3)
# iteration : 230/250	SHAPE (20, 480, 640, 3)
# iteration : 231/250	SHAPE (20, 480, 640, 3)
# iteration : 232/250	SHAPE (20, 480, 640, 3)
# iteration : 233/250	SHAPE (20, 480, 640, 3)
# iteration : 234/250	SHAPE (20, 480, 640, 3)
# iteration : 235/250	SHAPE (20, 480, 640, 3)
# iteration : 236/250	SHAPE (20, 480, 640, 3)
# iteration : 237/250	SHAPE (20, 480, 640, 3)
# iteration : 238/250	SHAPE (20, 480, 640, 3)
# iteration : 239/250	SHAPE (20, 480, 640, 3)
# iteration : 240/250	SHAPE (20, 480, 640, 3)
# iteration : 241/250	SHAPE (20, 480, 640, 3)
# iteration : 242/250	SHAPE (20, 480, 640, 3)
# iteration : 243/250	SHAPE (20, 480, 640, 3)
# iteration : 244/250	SHAPE (20, 480, 640, 3)
# iteration : 245/250	SHAPE (20, 480, 640, 3)
# iteration : 246/250	SHAPE (20, 480, 640, 3)
# iteration : 247/250	SHAPE (20, 480, 640, 3)
# iteration : 248/250	SHAPE (20, 480, 640, 3)
# iteration : 249/250	SHAPE (20, 480, 640, 3)
# iteration : 250/250	SHAPE (20, 480, 640, 3)

# %%
train.shape
# Out:
# (250, 20, 258)

# %% [markdown]
# ### 3.4 split the data (training,testing)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
labels = to_categorical(y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train, labels, test_size=0.1)

# %%
print(
X_train.shape,
X_test.shape,
Y_train.shape,
Y_test.shape,
)
# Out:
# (225, 20, 258) (25, 20, 258) (225, 5) (25, 5)

# %% [markdown]
# # 4 - build the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense,Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import TensorBoard

log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
input_layer = Input(shape=(20,258))
layer = LSTM(64,return_sequences=True,activation="relu")(input_layer)
layer = LSTM(128,return_sequences=True,activation="relu")(layer)
layer = LSTM(64,return_sequences=False,activation="relu")(layer)
layer = Dense(64,activation="relu")(layer)
layer = Dense(32,activation="relu")(layer)
layer = Dense(len(actions),activation="softmax")(layer)

model = Model(inputs=input_layer,outputs=layer)
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 20, 258)]         0
#
#  lstm_3 (LSTM)               (None, 20, 64)            82688
#
#  lstm_4 (LSTM)               (None, 20, 128)           98816
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 237,317
# Trainable params: 237,317
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, Y_train, epochs=1000, callbacks=[tb_callback],validation_data=(X_test,Y_test))
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 3s 89ms/step - loss: 1.5850 - categorical_accuracy: 0.2133 - val_loss: 1.4614 - val_categorical_accuracy: 0.4800
# Epoch 2/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 1.4271 - categorical_accuracy: 0.3778 - val_loss: 3.0159 - val_categorical_accuracy: 0.2800
# Epoch 3/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 1.5205 - categorical_accuracy: 0.4578 - val_loss: 1.4203 - val_categorical_accuracy: 0.3600
# Epoch 4/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 1.2898 - categorical_accuracy: 0.5156 - val_loss: 1.4298 - val_categorical_accuracy: 0.3200
# Epoch 5/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 1.1601 - categorical_accuracy: 0.5111 - val_loss: 1.0612 - val_categorical_accuracy: 0.4800
# Epoch 6/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 1.1586 - categorical_accuracy: 0.5467 - val_loss: 1.1873 - val_categorical_accuracy: 0.4800
# Epoch 7/1000
# 8/8 [==============================] - 0s 45ms/step - loss: 1.0513 - categorical_accuracy: 0.5333 - val_loss: 1.1703 - val_categorical_accuracy: 0.4800
# Epoch 8/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 1.2289 - categorical_accuracy: 0.4489 - val_loss: 1.2180 - val_categorical_accuracy: 0.3600
# Epoch 9/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 1.2250 - categorical_accuracy: 0.4622 - val_loss: 1.0734 - val_categorical_accuracy: 0.4800
# Epoch 10/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 1.2230 - categorical_accuracy: 0.5244 - val_loss: 1.3056 - val_categorical_accuracy: 0.4800
# Epoch 11/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 1.2970 - categorical_accuracy: 0.5289 - val_loss: 1.1830 - val_categorical_accuracy: 0.4800
# Epoch 12/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 1.0037 - categorical_accuracy: 0.5867 - val_loss: 0.9386 - val_categorical_accuracy: 0.5200
# Epoch 13/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 1.0010 - categorical_accuracy: 0.5422 - val_loss: 1.0919 - val_categorical_accuracy: 0.4800
# Epoch 14/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 1.1289 - categorical_accuracy: 0.5289 - val_loss: 1.1878 - val_categorical_accuracy: 0.3600
# Epoch 15/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 1.0400 - categorical_accuracy: 0.5067 - val_loss: 1.0237 - val_categorical_accuracy: 0.5600
# Epoch 16/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.8806 - categorical_accuracy: 0.5689 - val_loss: 0.8918 - val_categorical_accuracy: 0.5200
# Epoch 17/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.7653 - categorical_accuracy: 0.6311 - val_loss: 0.8047 - val_categorical_accuracy: 0.6800
# Epoch 18/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.7065 - categorical_accuracy: 0.6444 - val_loss: 0.6583 - val_categorical_accuracy: 0.7200
# Epoch 19/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.6130 - categorical_accuracy: 0.7111 - val_loss: 0.7354 - val_categorical_accuracy: 0.8400
# Epoch 20/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.7531 - categorical_accuracy: 0.6444 - val_loss: 0.8567 - val_categorical_accuracy: 0.7200
# Epoch 21/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.6951 - categorical_accuracy: 0.6978 - val_loss: 0.7736 - val_categorical_accuracy: 0.6800
# Epoch 22/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5931 - categorical_accuracy: 0.7778 - val_loss: 1.0915 - val_categorical_accuracy: 0.6000
# Epoch 23/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.8921 - categorical_accuracy: 0.6267 - val_loss: 0.8082 - val_categorical_accuracy: 0.7200
# Epoch 24/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.7707 - categorical_accuracy: 0.7822 - val_loss: 0.7657 - val_categorical_accuracy: 0.6800
# Epoch 25/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.8425 - categorical_accuracy: 0.7156 - val_loss: 1.0107 - val_categorical_accuracy: 0.6000
# Epoch 26/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.6051 - categorical_accuracy: 0.7911 - val_loss: 0.5562 - val_categorical_accuracy: 0.8800
# Epoch 27/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4504 - categorical_accuracy: 0.8356 - val_loss: 0.5754 - val_categorical_accuracy: 0.7600
# Epoch 28/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3882 - categorical_accuracy: 0.8622 - val_loss: 0.4745 - val_categorical_accuracy: 0.8400
# Epoch 29/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.7261 - categorical_accuracy: 0.7778 - val_loss: 0.5634 - val_categorical_accuracy: 0.7600
# Epoch 30/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.8226 - categorical_accuracy: 0.7156 - val_loss: 0.6618 - val_categorical_accuracy: 0.7600
# Epoch 31/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6534 - categorical_accuracy: 0.7156 - val_loss: 0.5357 - val_categorical_accuracy: 0.7600
# Epoch 32/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4763 - categorical_accuracy: 0.7822 - val_loss: 0.4186 - val_categorical_accuracy: 0.8400
# Epoch 33/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2885 - categorical_accuracy: 0.9067 - val_loss: 0.4213 - val_categorical_accuracy: 0.9200
# Epoch 34/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2257 - categorical_accuracy: 0.9289 - val_loss: 0.4090 - val_categorical_accuracy: 0.8400
# Epoch 35/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3260 - categorical_accuracy: 0.8933 - val_loss: 0.4707 - val_categorical_accuracy: 0.8000
# Epoch 36/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2641 - categorical_accuracy: 0.9111 - val_loss: 0.9065 - val_categorical_accuracy: 0.7200
# Epoch 37/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5851 - categorical_accuracy: 0.7778 - val_loss: 0.8032 - val_categorical_accuracy: 0.6800
# Epoch 38/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5036 - categorical_accuracy: 0.8267 - val_loss: 0.8212 - val_categorical_accuracy: 0.6400
# Epoch 39/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4097 - categorical_accuracy: 0.8667 - val_loss: 0.3875 - val_categorical_accuracy: 0.8800
# Epoch 40/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2942 - categorical_accuracy: 0.9111 - val_loss: 1.1435 - val_categorical_accuracy: 0.7200
# Epoch 41/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3427 - categorical_accuracy: 0.8800 - val_loss: 0.4863 - val_categorical_accuracy: 0.8800
# Epoch 42/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2208 - categorical_accuracy: 0.9156 - val_loss: 0.4576 - val_categorical_accuracy: 0.9200
# Epoch 43/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2326 - categorical_accuracy: 0.9067 - val_loss: 0.3737 - val_categorical_accuracy: 0.8800
# Epoch 44/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1836 - categorical_accuracy: 0.9333 - val_loss: 0.3589 - val_categorical_accuracy: 0.9200
# Epoch 45/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1389 - categorical_accuracy: 0.9422 - val_loss: 0.6433 - val_categorical_accuracy: 0.8800
# Epoch 46/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.2562 - categorical_accuracy: 0.9067 - val_loss: 0.5726 - val_categorical_accuracy: 0.8800
# Epoch 47/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2906 - categorical_accuracy: 0.8800 - val_loss: 0.5239 - val_categorical_accuracy: 0.8000
# Epoch 48/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2328 - categorical_accuracy: 0.9422 - val_loss: 0.5441 - val_categorical_accuracy: 0.7200
# Epoch 49/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2387 - categorical_accuracy: 0.9022 - val_loss: 0.3817 - val_categorical_accuracy: 0.8800
# Epoch 50/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1921 - categorical_accuracy: 0.9244 - val_loss: 0.4487 - val_categorical_accuracy: 0.8400
# Epoch 51/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1621 - categorical_accuracy: 0.9244 - val_loss: 0.5197 - val_categorical_accuracy: 0.8400
# Epoch 52/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1170 - categorical_accuracy: 0.9689 - val_loss: 0.3630 - val_categorical_accuracy: 0.8400
# Epoch 53/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0956 - categorical_accuracy: 0.9556 - val_loss: 0.7832 - val_categorical_accuracy: 0.8000
# Epoch 54/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 1.0166 - categorical_accuracy: 0.7778 - val_loss: 0.7127 - val_categorical_accuracy: 0.8000
# Epoch 55/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.7307 - categorical_accuracy: 0.7644 - val_loss: 0.8532 - val_categorical_accuracy: 0.8000
# Epoch 56/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.7355 - categorical_accuracy: 0.9067 - val_loss: 0.6282 - val_categorical_accuracy: 0.8400
# Epoch 57/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5048 - categorical_accuracy: 0.9156 - val_loss: 0.6118 - val_categorical_accuracy: 0.9200
# Epoch 58/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4440 - categorical_accuracy: 0.8667 - val_loss: 0.5946 - val_categorical_accuracy: 0.9200
# Epoch 59/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3309 - categorical_accuracy: 0.9022 - val_loss: 0.6824 - val_categorical_accuracy: 0.8800
# Epoch 60/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4029 - categorical_accuracy: 0.9244 - val_loss: 0.5208 - val_categorical_accuracy: 0.9200
# Epoch 61/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2956 - categorical_accuracy: 0.9333 - val_loss: 0.4823 - val_categorical_accuracy: 0.9200
# Epoch 62/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2092 - categorical_accuracy: 0.9378 - val_loss: 0.3543 - val_categorical_accuracy: 0.8800
# Epoch 63/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1840 - categorical_accuracy: 0.9467 - val_loss: 0.4727 - val_categorical_accuracy: 0.8400
# Epoch 64/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2611 - categorical_accuracy: 0.9200 - val_loss: 0.5726 - val_categorical_accuracy: 0.8400
# Epoch 65/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2859 - categorical_accuracy: 0.9111 - val_loss: 0.2479 - val_categorical_accuracy: 0.8800
# Epoch 66/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1964 - categorical_accuracy: 0.9422 - val_loss: 0.3311 - val_categorical_accuracy: 0.9200
# Epoch 67/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1609 - categorical_accuracy: 0.9556 - val_loss: 0.4006 - val_categorical_accuracy: 0.8400
# Epoch 68/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0951 - categorical_accuracy: 0.9644 - val_loss: 0.2288 - val_categorical_accuracy: 0.9200
# Epoch 69/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1014 - categorical_accuracy: 0.9556 - val_loss: 0.5003 - val_categorical_accuracy: 0.8400
# Epoch 70/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0873 - categorical_accuracy: 0.9689 - val_loss: 2.0513 - val_categorical_accuracy: 0.6400
# Epoch 71/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 1.7241 - categorical_accuracy: 0.5556 - val_loss: 0.7978 - val_categorical_accuracy: 0.7200
# Epoch 72/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.8430 - categorical_accuracy: 0.6889 - val_loss: 0.6975 - val_categorical_accuracy: 0.7600
# Epoch 73/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6811 - categorical_accuracy: 0.7156 - val_loss: 0.5911 - val_categorical_accuracy: 0.7600
# Epoch 74/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.1539 - categorical_accuracy: 0.7067 - val_loss: 0.8089 - val_categorical_accuracy: 0.6800
# Epoch 75/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.0571 - categorical_accuracy: 0.5556 - val_loss: 0.9667 - val_categorical_accuracy: 0.7200
# Epoch 76/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.9480 - categorical_accuracy: 0.6178 - val_loss: 0.8464 - val_categorical_accuracy: 0.7200
# Epoch 77/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.7122 - categorical_accuracy: 0.7511 - val_loss: 0.6320 - val_categorical_accuracy: 0.7600
# Epoch 78/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5509 - categorical_accuracy: 0.8400 - val_loss: 0.4754 - val_categorical_accuracy: 0.7600
# Epoch 79/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5356 - categorical_accuracy: 0.8267 - val_loss: 0.4058 - val_categorical_accuracy: 0.8400
# Epoch 80/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3873 - categorical_accuracy: 0.8978 - val_loss: 0.3997 - val_categorical_accuracy: 0.8000
# Epoch 81/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3619 - categorical_accuracy: 0.8800 - val_loss: 0.3061 - val_categorical_accuracy: 0.8400
# Epoch 82/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3819 - categorical_accuracy: 0.9244 - val_loss: 0.4750 - val_categorical_accuracy: 0.7600
# Epoch 83/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4954 - categorical_accuracy: 0.8222 - val_loss: 0.8067 - val_categorical_accuracy: 0.7600
# Epoch 84/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4425 - categorical_accuracy: 0.8178 - val_loss: 0.5145 - val_categorical_accuracy: 0.8000
# Epoch 85/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2806 - categorical_accuracy: 0.8978 - val_loss: 0.4031 - val_categorical_accuracy: 0.8400
# Epoch 86/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2225 - categorical_accuracy: 0.9067 - val_loss: 0.3978 - val_categorical_accuracy: 0.8400
# Epoch 87/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1670 - categorical_accuracy: 0.9378 - val_loss: 0.3492 - val_categorical_accuracy: 0.8400
# Epoch 88/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1612 - categorical_accuracy: 0.9378 - val_loss: 0.3581 - val_categorical_accuracy: 0.9200
# Epoch 89/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1223 - categorical_accuracy: 0.9556 - val_loss: 0.3789 - val_categorical_accuracy: 0.8800
# Epoch 90/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0952 - categorical_accuracy: 0.9689 - val_loss: 0.4043 - val_categorical_accuracy: 0.9200
# Epoch 91/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3486 - categorical_accuracy: 0.8800 - val_loss: 0.2697 - val_categorical_accuracy: 0.9600
# Epoch 92/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4710 - categorical_accuracy: 0.8489 - val_loss: 0.4597 - val_categorical_accuracy: 0.8400
# Epoch 93/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2855 - categorical_accuracy: 0.9378 - val_loss: 0.3098 - val_categorical_accuracy: 0.9200
# Epoch 94/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1710 - categorical_accuracy: 0.9600 - val_loss: 0.3697 - val_categorical_accuracy: 0.9200
# Epoch 95/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1438 - categorical_accuracy: 0.9511 - val_loss: 0.3787 - val_categorical_accuracy: 0.8800
# Epoch 96/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.0884 - categorical_accuracy: 0.9644 - val_loss: 0.3981 - val_categorical_accuracy: 0.9200
# Epoch 97/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1628 - categorical_accuracy: 0.9422 - val_loss: 0.7512 - val_categorical_accuracy: 0.7600
# Epoch 98/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1911 - categorical_accuracy: 0.9333 - val_loss: 0.5902 - val_categorical_accuracy: 0.8800
# Epoch 99/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2983 - categorical_accuracy: 0.9067 - val_loss: 0.8104 - val_categorical_accuracy: 0.7600
# Epoch 100/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2571 - categorical_accuracy: 0.9289 - val_loss: 0.4267 - val_categorical_accuracy: 0.8800
# Epoch 101/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5497 - categorical_accuracy: 0.7956 - val_loss: 0.9148 - val_categorical_accuracy: 0.6800
# Epoch 102/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5020 - categorical_accuracy: 0.8311 - val_loss: 0.4813 - val_categorical_accuracy: 0.8800
# Epoch 103/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2066 - categorical_accuracy: 0.9467 - val_loss: 0.4323 - val_categorical_accuracy: 0.8000
# Epoch 104/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1357 - categorical_accuracy: 0.9644 - val_loss: 0.3622 - val_categorical_accuracy: 0.9200
# Epoch 105/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1879 - categorical_accuracy: 0.9644 - val_loss: 1.3916 - val_categorical_accuracy: 0.7200
# Epoch 106/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5544 - categorical_accuracy: 0.8222 - val_loss: 0.5593 - val_categorical_accuracy: 0.8400
# Epoch 107/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2328 - categorical_accuracy: 0.9511 - val_loss: 0.2169 - val_categorical_accuracy: 0.9200
# Epoch 108/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1611 - categorical_accuracy: 0.9556 - val_loss: 0.2530 - val_categorical_accuracy: 0.9200
# Epoch 109/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0859 - categorical_accuracy: 0.9822 - val_loss: 0.3927 - val_categorical_accuracy: 0.8800
# Epoch 110/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0917 - categorical_accuracy: 0.9778 - val_loss: 0.9596 - val_categorical_accuracy: 0.8000
# Epoch 111/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2398 - categorical_accuracy: 0.9378 - val_loss: 0.1679 - val_categorical_accuracy: 0.9600
# Epoch 112/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1221 - categorical_accuracy: 0.9556 - val_loss: 0.4831 - val_categorical_accuracy: 0.8800
# Epoch 113/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0572 - categorical_accuracy: 0.9822 - val_loss: 0.4819 - val_categorical_accuracy: 0.9200
# Epoch 114/1000
# 8/8 [==============================] - 0s 45ms/step - loss: 0.0370 - categorical_accuracy: 0.9911 - val_loss: 0.2263 - val_categorical_accuracy: 0.9600
# Epoch 115/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0178 - categorical_accuracy: 1.0000 - val_loss: 0.2779 - val_categorical_accuracy: 0.9600
# Epoch 116/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 0.0125 - categorical_accuracy: 0.9956 - val_loss: 0.4257 - val_categorical_accuracy: 0.9200
# Epoch 117/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0355 - categorical_accuracy: 0.9911 - val_loss: 0.4935 - val_categorical_accuracy: 0.8400
# Epoch 118/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0770 - categorical_accuracy: 0.9867 - val_loss: 0.7266 - val_categorical_accuracy: 0.8800
# Epoch 119/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0214 - categorical_accuracy: 0.9911 - val_loss: 0.1117 - val_categorical_accuracy: 0.9600
# Epoch 120/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0240 - categorical_accuracy: 0.9911 - val_loss: 0.7597 - val_categorical_accuracy: 0.9200
# Epoch 121/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0120 - categorical_accuracy: 1.0000 - val_loss: 0.4197 - val_categorical_accuracy: 0.8800
# Epoch 122/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0092 - categorical_accuracy: 1.0000 - val_loss: 0.3085 - val_categorical_accuracy: 0.9200
# Epoch 123/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0037 - categorical_accuracy: 1.0000 - val_loss: 0.2624 - val_categorical_accuracy: 0.9200
# Epoch 124/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0035 - categorical_accuracy: 1.0000 - val_loss: 0.2301 - val_categorical_accuracy: 0.9200
# Epoch 125/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0026 - categorical_accuracy: 1.0000 - val_loss: 0.2236 - val_categorical_accuracy: 0.9200
# Epoch 126/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.2714 - val_categorical_accuracy: 0.9200
# Epoch 127/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 0.3279 - val_categorical_accuracy: 0.9200
# Epoch 128/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.3519 - val_categorical_accuracy: 0.8800
# Epoch 129/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 0.3377 - val_categorical_accuracy: 0.9200
# Epoch 130/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0010 - categorical_accuracy: 1.0000 - val_loss: 0.3273 - val_categorical_accuracy: 0.9200
# Epoch 131/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 9.0243e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3260 - val_categorical_accuracy: 0.9200
# Epoch 132/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 7.9469e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3324 - val_categorical_accuracy: 0.9200
# Epoch 133/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 7.1153e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3425 - val_categorical_accuracy: 0.8800
# Epoch 134/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 6.1916e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3564 - val_categorical_accuracy: 0.8800
# Epoch 135/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 5.5066e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3488 - val_categorical_accuracy: 0.9200
# Epoch 136/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 4.8123e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3685 - val_categorical_accuracy: 0.9200
# Epoch 137/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 4.2598e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3632 - val_categorical_accuracy: 0.8800
# Epoch 138/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 3.6749e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3657 - val_categorical_accuracy: 0.8800
# Epoch 139/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 3.2956e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3648 - val_categorical_accuracy: 0.8800
# Epoch 140/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 2.8991e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3412 - val_categorical_accuracy: 0.8800
# Epoch 141/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 2.6049e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3454 - val_categorical_accuracy: 0.8800
# Epoch 142/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 2.3706e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3809 - val_categorical_accuracy: 0.8800
# Epoch 143/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 2.0743e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3853 - val_categorical_accuracy: 0.8800
# Epoch 144/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 1.8197e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3692 - val_categorical_accuracy: 0.8800
# Epoch 145/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.6287e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3623 - val_categorical_accuracy: 0.8800
# Epoch 146/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 1.4481e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3797 - val_categorical_accuracy: 0.8800
# Epoch 147/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 1.2795e-04 - categorical_accuracy: 1.0000 - val_loss: 0.3920 - val_categorical_accuracy: 0.8800
# Epoch 148/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 1.1259e-04 - categorical_accuracy: 1.0000 - val_loss: 0.4365 - val_categorical_accuracy: 0.8800
# Epoch 149/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.1011e-04 - categorical_accuracy: 1.0000 - val_loss: 0.6164 - val_categorical_accuracy: 0.8800
# Epoch 150/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 1.6954e-04 - categorical_accuracy: 1.0000 - val_loss: 0.5289 - val_categorical_accuracy: 0.8800
# Epoch 151/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 8.9759e-05 - categorical_accuracy: 1.0000 - val_loss: 0.2075 - val_categorical_accuracy: 0.8800
# Epoch 152/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 9.2914e-05 - categorical_accuracy: 1.0000 - val_loss: 0.1303 - val_categorical_accuracy: 0.8800
# Epoch 153/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 9.2561e-05 - categorical_accuracy: 1.0000 - val_loss: 0.1665 - val_categorical_accuracy: 0.8800
# Epoch 154/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 7.7488e-05 - categorical_accuracy: 1.0000 - val_loss: 0.2285 - val_categorical_accuracy: 0.8800
# Epoch 155/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 6.4736e-05 - categorical_accuracy: 1.0000 - val_loss: 0.2587 - val_categorical_accuracy: 0.8800
# Epoch 156/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 5.7564e-05 - categorical_accuracy: 1.0000 - val_loss: 0.2793 - val_categorical_accuracy: 0.8800
# Epoch 157/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 5.2259e-05 - categorical_accuracy: 1.0000 - val_loss: 0.3072 - val_categorical_accuracy: 0.8800
# Epoch 158/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 4.7242e-05 - categorical_accuracy: 1.0000 - val_loss: 0.3360 - val_categorical_accuracy: 0.8800
# Epoch 159/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 4.3104e-05 - categorical_accuracy: 1.0000 - val_loss: 0.3620 - val_categorical_accuracy: 0.8800
# Epoch 160/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 3.8087e-05 - categorical_accuracy: 1.0000 - val_loss: 0.4404 - val_categorical_accuracy: 0.8800
# Epoch 161/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 3.5266e-05 - categorical_accuracy: 1.0000 - val_loss: 0.4811 - val_categorical_accuracy: 0.8800
# Epoch 162/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 3.1782e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5205 - val_categorical_accuracy: 0.8800
# Epoch 163/1000
# 8/8 [==============================] - 0s 49ms/step - loss: 3.5949e-05 - categorical_accuracy: 1.0000 - val_loss: 0.7523 - val_categorical_accuracy: 0.8800
# Epoch 164/1000
# 8/8 [==============================] - 0s 50ms/step - loss: 4.0504e-05 - categorical_accuracy: 1.0000 - val_loss: 0.6460 - val_categorical_accuracy: 0.8800
# Epoch 165/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 2.4868e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5505 - val_categorical_accuracy: 0.8800
# Epoch 166/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 2.3264e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5012 - val_categorical_accuracy: 0.8800
# Epoch 167/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 2.1528e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5099 - val_categorical_accuracy: 0.8800
# Epoch 168/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 1.9131e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5291 - val_categorical_accuracy: 0.8800
# Epoch 169/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 1.7607e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5495 - val_categorical_accuracy: 0.8800
# Epoch 170/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.6288e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5689 - val_categorical_accuracy: 0.8800
# Epoch 171/1000
# 8/8 [==============================] - 0s 46ms/step - loss: 1.4818e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5807 - val_categorical_accuracy: 0.8800
# Epoch 172/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.4055e-05 - categorical_accuracy: 1.0000 - val_loss: 0.5982 - val_categorical_accuracy: 0.8800
# Epoch 173/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 1.3063e-05 - categorical_accuracy: 1.0000 - val_loss: 0.6116 - val_categorical_accuracy: 0.8800
# Epoch 174/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.1944e-05 - categorical_accuracy: 1.0000 - val_loss: 0.6257 - val_categorical_accuracy: 0.8800
# Epoch 175/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.1008e-05 - categorical_accuracy: 1.0000 - val_loss: 0.6480 - val_categorical_accuracy: 0.8800
# Epoch 176/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 1.0278e-05 - categorical_accuracy: 1.0000 - val_loss: 0.6687 - val_categorical_accuracy: 0.8800
# Epoch 177/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 9.6820e-06 - categorical_accuracy: 1.0000 - val_loss: 0.7000 - val_categorical_accuracy: 0.8800
# Epoch 178/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 8.8314e-06 - categorical_accuracy: 1.0000 - val_loss: 0.7323 - val_categorical_accuracy: 0.8800
# Epoch 179/1000
# 5/8 [=================>............] - ETA: 0s - loss: 1.1245e-05 - categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_65564/2868692776.py in <module>
# ----> 1 model.fit(X_train, Y_train, epochs=1000, callbacks=[tb_callback],validation_data=(X_test,Y_test))
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.save_weights("model.h5")

# %%
model.load_weights('model.h5')

# %% [markdown]
# # 5 - Make predictions

# %% [markdown]
# ### this doesn't make any sence

# %%
model.evaluate(X_test,Y_test)
# Out:
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7528 - categorical_accuracy: 0.8800
# [0.7527683973312378, 0.8799999952316284]

# %%
model.evaluate(X_train,Y_train)
# Out:
# 8/8 [==============================] - 0s 9ms/step - loss: 7.8693e-06 - categorical_accuracy: 1.0000
# [7.869308319641277e-06, 1.0]

# %%
x[0]
# Out:
# '../../data/train/signer0_sample431_color.mp4'

# %% [markdown]
# # 6 - test in real time

# %%
model.predict(np.array([train[0]]))
# Out:
# array([[9.9999952e-01, 2.4448259e-11, 3.1743037e-18, 4.4404717e-07,
#         1.1752664e-15]], dtype=float32)

# %%
from scipy import stats

colors = [(245,117,16), (117,245,16), (16,117,245),(255,0,0),(0,255,0)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
        if(not ret):
            break
        frame = cv2.resize(frame, (640, 480))

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-20:]
        
        if len(sequence) == 20:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-2:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()

# %%
cv2.destroyAllWindows()
