# %% [markdown]
# # **Download Dataset**

# %% [markdown]
# ## Training Dataset

# %% [markdown]
# ### Download Dataset

# %%
BASE_LINK = "http://158.109.8.102/AuTSL/data/train/train_set_vfbha39.zip."
START_PART = 1
END_PART = 19
for i in range(START_PART, END_PART):
    PART = "0"
    if (i >= 1 and i < 10):
        PART = PART + "0" + str(i)
    else:
        PART = PART + str(i)
    LINK = BASE_LINK + PART
    # !wget $LINK
# Out:
# --2021-12-24 07:11:56--  http://158.109.8.102/AuTSL/data/train/train_set_vfbha39.zip.001
# Connecting to 158.109.8.102:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1048576000 (1000M) [application/octet-stream]
# Saving to: ‘train_set_vfbha39.zip.001’
#
# train_set_vfbha39.z 100%[===================>]   1000M  4.55MB/s    in 7m 2s
#
# 2021-12-24 07:18:59 (2.37 MB/s) - ‘train_set_vfbha39.zip.001’ saved [1048576000/1048576000]
#
# --2021-12-24 07:18:59--  http://158.109.8.102/AuTSL/data/train/train_set_vfbha39.zip.002
# Connecting to 158.109.8.102:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1048576000 (1000M) [application/octet-stream]
# Saving to: ‘train_set_vfbha39.zip.002’
#
# train_set_vfbha39.z 100%[===================>]   1000M  4.80MB/s    in 9m 19s
#
# 2021-12-24 07:28:18 (1.79 MB/s) - ‘train_set_vfbha39.zip.002’ saved [1048576000/1048576000]
#
# ...

# %% [markdown]
# ### Unziping Dataset
#
# *Password:* *MdG3z6Eh1t*

# %%
!7z x train_set_vfbha39.zip.001 -pMdG3z6Eh1t
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,4 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1048576000 bytes (1000 MiB)
#
# Extracting archive: train_set_vfbha39.zip.001
# --
# Path = train_set_vfbha39.zip.001
# Type = Split
# Physical Size = 1048576000
# Volumes = 18
# Total Physical Size = 18514780403
# ----
# Path = train_set_vfbha39.zip
# Size = 18514780403
# --
# Path = train_set_vfbha39.zip
# Type = zip
# Physical Size = 18514780403
# 64-bit = +
#
#   0%
# Enter password (will not be echoed):
# Everything is Ok
#
# Folders: 1
# Files: 56284
# Size:       19111761758
# Compressed: 18514780403

# %% [markdown]
# ### Download Labels

# %%
# !wget http://158.109.8.102/AuTSL/data/train/train_labels.csv
# Out:
# --2021-12-24 08:48:19--  http://158.109.8.102/AuTSL/data/train/train_labels.csv
# Connecting to 158.109.8.102:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 653817 (638K) [application/octet-stream]
# Saving to: ‘train_labels.csv’
#
# train_labels.csv    100%[===================>] 638.49K   456KB/s    in 1.4s
#
# 2021-12-24 08:48:21 (456 KB/s) - ‘train_labels.csv’ saved [653817/653817]

# %% [markdown]
# ## Validation Dataset

# %% [markdown]
# ### Download Dataset

# %%
BASE_LINK = "http://158.109.8.102/AuTSL/data/validation/val_set_bjhfy68.zip."
START_PART = 1
END_PART = 4
for i in range(START_PART, END_PART):
    PART = "0"
    if (i >= 1 and i < 10):
        PART = PART + "0" + str(i)
    else:
        PART = PART + str(i)
    LINK = BASE_LINK + PART
    # !wget $LINK
# Out:
# --2021-12-24 08:51:15--  http://158.109.8.102/AuTSL/data/validation/val_set_bjhfy68.zip.001
# Connecting to 158.109.8.102:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1048576000 (1000M) [application/octet-stream]
# Saving to: ‘val_set_bjhfy68.zip.001’
#
# val_set_bjhfy68.zip 100%[===================>]   1000M  6.19MB/s    in 2m 53s
#
# 2021-12-24 08:54:09 (5.77 MB/s) - ‘val_set_bjhfy68.zip.001’ saved [1048576000/1048576000]
#
# --2021-12-24 08:54:09--  http://158.109.8.102/AuTSL/data/validation/val_set_bjhfy68.zip.002
# Connecting to 158.109.8.102:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1048576000 (1000M) [application/octet-stream]
# Saving to: ‘val_set_bjhfy68.zip.002’
#
# val_set_bjhfy68.zip 100%[===================>]   1000M  6.39MB/s    in 3m 14s
#
# 2021-12-24 08:57:24 (5.16 MB/s) - ‘val_set_bjhfy68.zip.002’ saved [1048576000/1048576000]
#
# ...

# %% [markdown]
# ### Unziping Dataset
#
# *Password:* *bhRY5B9zS2*

# %%
!7z x val_set_bjhfy68.zip.001 -pbhRY5B9zS2
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,4 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1048576000 bytes (1000 MiB)
#
# Extracting archive: val_set_bjhfy68.zip.001
# --
# Path = val_set_bjhfy68.zip.001
# Type = Split
# Physical Size = 1048576000
# Volumes = 3
# Total Physical Size = 3125796777
# ----
# Path = val_set_bjhfy68.zip
# Size = 3125796777
# --
# Path = val_set_bjhfy68.zip
# Type = zip
# Physical Size = 3125796777
#
# Everything is Ok
#
# Folders: 1
# Files: 8836
# Size:       3218995247
# Compressed: 3125796777

# %% [markdown]
# ### Download Labels

# %%
# !wget http://158.109.8.102/AuTSL/data/validation/validation_labels.zip
# Out:
# --2021-12-24 09:01:56--  http://158.109.8.102/AuTSL/data/validation/validation_labels.zip
# Connecting to 158.109.8.102:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18909 (18K) [application/zip]
# Saving to: ‘validation_labels.zip’
#
# validation_labels.z 100%[===================>]  18.47K  67.6KB/s    in 0.3s
#
# 2021-12-24 09:01:56 (67.6 KB/s) - ‘validation_labels.zip’ saved [18909/18909]

# %% [markdown]
# ### Unziping Labels
#
# *Password:* *zYX5W7fZ*

# %%
!7z x validation_labels.zip -pzYX5W7fZ
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,4 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 18909 bytes (19 KiB)
#
# Extracting archive: validation_labels.zip
# --
# Path = validation_labels.zip
# Type = zip
# Physical Size = 18909
#
# Everything is Ok
#
# Size:       102264
# Compressed: 18909

# %%
# !mv ground_truth.csv val_labels.csv

# %% [markdown]
# ## Test Dataset

# %% [markdown]
# ### Download Dataset

# %%
BASE_LINK = "http://158.109.8.102/AuTSL/data/test/test_set_xsaft57.zip."
START_PART = 1
END_PART = 4
for i in range(START_PART, END_PART):
    PART = "0"
    if (i >= 1 and i < 10):
        PART = PART + "0" + str(i)
    else:
        PART = PART + str(i)
    LINK = BASE_LINK + PART
    # !wget $LINK
# Out:
# --2021-12-24 09:02:15--  http://158.109.8.102/AuTSL/data/test/test_set_xsaft57.zip.001
# Connecting to 158.109.8.102:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1048576000 (1000M) [application/octet-stream]
# Saving to: ‘test_set_xsaft57.zip.001’
#
# test_set_xsaft57.zi 100%[===================>]   1000M  4.00MB/s    in 2m 51s
#
# 2021-12-24 09:05:07 (5.84 MB/s) - ‘test_set_xsaft57.zip.001’ saved [1048576000/1048576000]
#
# --2021-12-24 09:05:08--  http://158.109.8.102/AuTSL/data/test/test_set_xsaft57.zip.002
# Connecting to 158.109.8.102:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1048576000 (1000M) [application/octet-stream]
# Saving to: ‘test_set_xsaft57.zip.002’
#
# test_set_xsaft57.zi 100%[===================>]   1000M  7.93MB/s    in 2m 54s
#
# 2021-12-24 09:08:02 (5.74 MB/s) - ‘test_set_xsaft57.zip.002’ saved [1048576000/1048576000]
#
# ...

# %% [markdown]
# ### Unziping Dataset
#
# *Password:* *ds6Kvdus3o*

# %%
!7z x test_set_xsaft57.zip.001 -pds6Kvdus3o
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,4 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1048576000 bytes (1000 MiB)
#
# Extracting archive: test_set_xsaft57.zip.001
# --
# Path = test_set_xsaft57.zip.001
# Type = Split
# Physical Size = 1048576000
# Volumes = 3
# Total Physical Size = 2693843542
# ----
# Path = test_set_xsaft57.zip
# Size = 2693843542
# --
# Path = test_set_xsaft57.zip
# Type = zip
# Physical Size = 2693843542
#
# Everything is Ok
#
# Folders: 1
# Files: 7484
# Size:       2796878753
# Compressed: 2693843542

# %% [markdown]
# ### Download Labels

# %%
# !wget http://158.109.8.102/AuTSL/data/test/test_labels.zip
# Out:
# --2021-12-24 09:11:00--  http://158.109.8.102/AuTSL/data/test/test_labels.zip
# Connecting to 158.109.8.102:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16102 (16K) [application/zip]
# Saving to: ‘test_labels.zip’
#
# test_labels.zip     100%[===================>]  15.72K  56.7KB/s    in 0.3s
#
# 2021-12-24 09:11:01 (56.7 KB/s) - ‘test_labels.zip’ saved [16102/16102]

# %% [markdown]
# ### Unziping Labels
#
# *Password:* *ds6Kvdus3o*

# %%
!7z x test_labels.zip -pds6Kvdus3o
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,4 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 16102 bytes (16 KiB)
#
# Extracting archive: test_labels.zip
# --
# Path = test_labels.zip
# Type = zip
# Physical Size = 16102
#
# Everything is Ok
#
# Size:       86676
# Compressed: 16102

# %%
# !mv ground_truth.csv test_labels.csv

# %% [markdown]
# ## Download Class Id

# %%
# !wget https://data.chalearnlap.cvc.uab.cat/AuTSL/data/SignList_ClassId_TR_EN.csv
# Out:
# --2021-12-24 09:14:52--  https://data.chalearnlap.cvc.uab.cat/AuTSL/data/SignList_ClassId_TR_EN.csv
# Resolving data.chalearnlap.cvc.uab.cat (data.chalearnlap.cvc.uab.cat)... 158.109.8.102
# Connecting to data.chalearnlap.cvc.uab.cat (data.chalearnlap.cvc.uab.cat)|158.109.8.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [application/octet-stream]
# Saving to: ‘SignList_ClassId_TR_EN.csv’
#
# SignList_ClassId_TR 100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2021-12-24 09:14:54 (661 MB/s) - ‘SignList_ClassId_TR_EN.csv’ saved [4063/4063]

# %%
# !mv SignList_ClassId_TR_EN.csv class_id.csv

# %% [markdown]
# ## Create folders and move videos

# %%
# !mkdir Datasets
# !mkdir Datasets/AUTSL
# !mv train Datasets/AUTSL
# !mv val Datasets/AUTSL
# !mv test Datasets/AUTSL

# !mkdir labels
# !mv train_labels.csv labels
# !mv val_labels.csv labels
# !mv test_labels.csv labels
# !mv class_id.csv labels
# !mv labels Datasets/AUTSL/

# !mkdir "prepared dataset"
# !mkdir "prepared dataset"/train
# !mkdir "prepared dataset"/val
# !mkdir "prepared dataset"/test

# !mkdir "weights"

# %% [markdown]
# # **Data Preprocessing**

# %%
WEIGHTS_V = 41

# %% [markdown]
# ## *Select Classes*

# %%
import pandas as pd
import os

# %%
data_path = "../Datasets/AUTSL"

train_labels = pd.read_csv(os.path.join(data_path,"labels/train_labels.csv"),names=['sample','id'])
validation_labels = pd.read_csv(os.path.join(data_path,"labels/val_labels.csv"),names=['sample','id'])
test_labels = pd.read_csv(os.path.join(data_path,"labels/test_labels.csv"),names=['sample','id'])
class_id = pd.read_csv(os.path.join(data_path,"labels/class_id.csv"))


    
train_path = os.path.join(data_path,"train")
val_path = os.path.join(data_path,"val")
test_path = os.path.join(data_path,"test")

train_labels.head()
# Out:
#             sample   id
# 0  signer0_sample1   41
# 1  signer0_sample2  104
# 2  signer0_sample3  205
# 3  signer0_sample4   26
# 4  signer0_sample5  191

# %%
def check_file(file_path):
    try:
        f = open(file_path)
        f.close()
        return True
    except IOError:
        return False
    
def construct_path(file,path="train"):
    return os.path.join(os.path.join(data_path,path),file+"_color.mp4")

# %%
n_classes = 100
actions = list(class_id['EN'][:n_classes])
dic={}
for i,action in enumerate(actions):
    dic[action]=i

# %%
def get_data(id,file_path):
    if file_path=="train":
        label_dic = train_labels
    elif file_path=="val":
        label_dic = validation_labels
    elif file_path=="test":
        label_dic = test_labels
        
    
    data =  label_dic[label_dic['id']==id]
    lis =  [construct_path(i,file_path) for i in  (data['sample'])]
    data =  [i for i in lis if check_file(i)]
    return data,[id for i in data]

# %%
train_X = [] 
train_Y = []
val_X = [] 
val_Y = []
test_X = [] 
test_Y = []

for i in range(n_classes):
    data,labels = get_data(i,'train')
    train_X.extend(data)
    train_Y.extend(labels)

    
for i in range(n_classes):
    data,labels = get_data(i,'val')
    val_X.extend(data)
    val_Y.extend(labels)

    
for i in range(n_classes):
    data,labels = get_data(i,'test')
    test_X.extend(data)
    test_Y.extend(labels)

# %%
video_path = train_X[0]
def_input_path = "../Datasets/AUTSL/train/"
video_path[len(def_input_path):-4]
# Out:
# 'signer0_sample431_color'

# %% [markdown]
# ## *Prepare Videos*

# %%
import os
import cv2
import numpy as np
from PIL import Image

# %%
def get_frames(video_path, n_frames=1):
    frames = []
    v_cap = cv2.VideoCapture(video_path)
    v_len = int(v_cap.get(cv2.CAP_PROP_FRAME_COUNT)) + 1
    frame_list = np.linspace(0, v_len-1, n_frames+1, dtype=np.int16)

    for fn in range(v_len):
        success, frame = v_cap.read()
        if success == False:
            continue
        if fn in frame_list:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame = Image.fromarray(frame)
            frames.append(frame)
    v_cap.release()
    return frames

def store_frames(frames, path_to_store):
    for i, frame in enumerate(frames):
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        path = os.path.join(path_to_store, "frame"+str(i)+".jpg")
        cv2.imwrite(path, frame)

# %% [markdown]
# # **Dataset**

# %% [markdown]
# ## *Build Dataset Class*

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import random

from utils.rgb_frames.data_prepare import get_frames

# %%
import matplotlib.pyplot as plt
from torchvision.transforms.functional import to_pil_image

def denormalize(x_, mean, std):
    x = x_.clone()
    for i in range(3):
        x[i] = x[i]*std[i]+mean[i]
    x = to_pil_image(x)        
    return x

# %%
np.random.seed(2020)
random.seed(2020)
torch.manual_seed(2020)

class VideoDataset(Dataset):
    def __init__(self, imgs_path, labels, n_frames, transform = None):
        super(VideoDataset, self).__init__()
        self.labels = labels
        self.transform = transform
        self.n_frames = n_frames
        self.imgs_path = imgs_path
    
    def __len__(self):
        return len(self.imgs_path)

    def __getitem__(self, idx):
        img_path = self.imgs_path[idx]
        frames = get_frames(video_path=img_path, n_frames=self.n_frames)        
        seed = np.random.randint(1e9)
        if self.transform:
            for i in range(len(frames)):
                random.seed(seed)
                np.random.seed(seed)
                frames[i] = self.transform(frames[i])
        if len(frames) > 0:
            frames = torch.stack(frames)

        return frames, self.labels[idx]

# %% [markdown]
# # **Models**

# %% [markdown]
# ## *Utils*

# %%
import copy

# %%
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

# %%
def metrics_batch(output, target):
    pred = output.argmax(dim=1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects

# %%
def loss_batch(loss_func, output, target, opt=None):
    loss = loss_func(output, target)
    with torch.no_grad():
        metric_b = metrics_batch(output, target)
    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()
    return loss.item(), metric_b

# %%
from tqdm import tqdm
import gc

def loss_epoch(model, loss_func, dataset_dl, device, opt=None):
    running_loss=0.0
    running_metric=0.0
    len_data = len(dataset_dl.dataset)
    for xb, yb in tqdm(dataset_dl):
        xb, yb = xb.to(device), yb.to(device)
        model = model.to(device)
        output=model(xb)
        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)
        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b
        
        del xb
        del yb
        gc.collect()

    loss = running_loss/float(len_data)
    metric = running_metric/float(len_data)
    return loss, metric

# %%
def train_val(model, loss_func, opt, train_dl, val_dl, lr_scheduler, start_epoch, end_epoch, path_to_weights, path_to_checkpoint, device, loss_history=None, metric_history=None):   
    if loss_history is None:
        loss_history={
            "train": [],
            "val": [],
        }
    if metric_history is None:
        metric_history={
            "train": [],
            "val": [],
        }
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_opt_hyp_params = copy.deepcopy(opt.state_dict())
    best_lr_scheduler_hyp_params = copy.deepcopy(lr_scheduler.state_dict())
    best_loss_hyp_params = copy.deepcopy(loss_func.state_dict())
    best_epoch = 0

    best_loss=float('inf')
    
    for epoch in range(start_epoch, end_epoch):
        current_lr=get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, end_epoch - 1, current_lr))
        print("Training")
        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, device, opt)
        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)
        print("Validation")
        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, device)
        
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            best_opt_hyp_params = copy.deepcopy(opt.state_dict())
            best_lr_scheduler_hyp_params = copy.deepcopy(lr_scheduler.state_dict())
            best_loss_hyp_params = copy.deepcopy(loss_func.state_dict())
            best_epoch = epoch
            checkpoint = {
                "epochs": end_epoch,
                "last_epoch": epoch,
                "best_epoch": best_epoch,
                "model_state_dict": best_model_wts,
                "optimizer_state_dict": best_opt_hyp_params,
                "lr_scheduler_state_dict": best_lr_scheduler_hyp_params,
                "loss_state_dict": best_loss_hyp_params,
                "hist": {
                    "loss": loss_history,
                    "metric": metric_history
                }
            }
            torch.save(checkpoint, path_to_weights)
            print("Copied best model weights!")
        
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print("Loading best model weights!")
            model.load_state_dict(best_model_wts)


        print("train loss: %.6f, train_accuracy: %.2f, val_loss: %.6f, val_accuracy: %.2f" %(train_loss, 100*train_metric, val_loss, 100*val_metric))        
        checkpoint = {
                "epochs": end_epoch,
                "last_epoch": epoch,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": opt.state_dict(),
                "lr_scheduler_state_dict": lr_scheduler.state_dict(),
                "loss_state_dict": loss_func.state_dict(),
                "hist": {
                    "loss": loss_history,
                    "metric": metric_history
                }
            }
        torch.save(checkpoint, path_to_checkpoint)
        print("Checkpoint saved")
        

        print("-"*10) 
    model.load_state_dict(best_model_wts)
        
    return model, loss_history, metric_history

# %%
def plot_loss(loss_hist, metric_hist):

    num_epochs= len(loss_hist["train"])

    plt.title("Train-Val Loss")
    plt.plot(range(1,num_epochs+1),loss_hist["train"],label="train")
    plt.plot(range(1,num_epochs+1),loss_hist["val"],label="val")
    plt.ylabel("Loss")
    plt.xlabel("Training Epochs")
    plt.legend()
    plt.show()

    plt.title("Train-Val Accuracy")
    plt.plot(range(1,num_epochs+1), metric_hist["train"],label="train")
    plt.plot(range(1,num_epochs+1), metric_hist["val"],label="val")
    plt.ylabel("Accuracy")
    plt.xlabel("Training Epochs")
    plt.legend()
    plt.show()

# %% [markdown]
# ## *Build Models*

# %% [markdown]
# #### **1. Conv3D**

# %%
import os
import torch
import torch.nn as nn
import torchvision

# %%
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
sys.path.insert(0, current_dir)

# %%
def convert_relu_to_swish(model: nn.Module):
    for child_name, child in model.named_children():
        if isinstance(child, nn.ReLU):
            setattr(model, child_name, nn.SiLU(True))
        else:
            convert_relu_to_swish(child)

# %%
class Swish(nn.Module):
    def __init(self):
        super().__init__()

    def forward(self, x):
        return x.mult_(torch.sigmoid(x))

# %%
class r2plus1d_18(nn.Module):
    def __init__(self, pretrained=True, n_classes=3, dropout_p=0.5):
        super(r2plus1d_18, self).__init__()
        self.pretrained = pretrained
        self.n_classes = n_classes

        model = torchvision.models.video.r2plus1d_18(pretrained=self.pretrained)
        modules = list(model.children())[:-1]
        self.r2plus1d_18 = nn.Sequential(*modules)
        convert_relu_to_swish(self.r2plus1d_18)
        self.fc1 = nn.Linear(model.fc.in_features, self.n_classes)
        self.dropout = nn.Dropout(dropout_p, inplace=True)

    def forward(self, x):
        # (b, f, c, h, w) = x.size()
        # x = x.view(b, c, f, h, w)

        out = self.r2plus1d_18(x)
        out = out.flatten(1)
        out = self.dropout(out)
        out = self.fc1(out)

        return out

# %% [markdown]
# # **Implementation**

# %% [markdown]
# ## *Create training, validation, testing datasets*

# %%
model_type = "3dcnn"
# model_type = "rnn"

n_frames = 22

if model_type == "rnn":
    h, w =224, 224
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
else:
    h, w = 128, 128
    mean = [0.43216, 0.394666, 0.37645]
    std = [0.22803, 0.22145, 0.216989]

# %%
import torchvision.transforms as transforms
from matplotlib import pyplot as plt

from utils.rgb_frames.data_prepare import denormalize

# %%
train_transformer = transforms.Compose([
                        transforms.Resize((h, w)),
                        transforms.RandomHorizontalFlip(p=0.5),
                        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
                        transforms.ToTensor(),
                        transforms.Normalize(mean, std)
                        ])


train_ds = VideoDataset(imgs_path=train_X, labels=train_Y, n_frames=n_frames, transform=train_transformer)
len(train_ds)
# Out:
# 12359

# %%
imgs, label = train_ds[0]
plt.imshow(denormalize(imgs[10], mean, std))

# %%
val_transofrmer = transforms.Compose([
                        transforms.Resize((h, w)),
                        transforms.ToTensor(),
                        transforms.Normalize(mean, std)
                        ])

val_ds = VideoDataset(imgs_path=val_X, labels=val_Y, n_frames=n_frames, transform=val_transofrmer)
len(val_ds)
# Out:
# 1931

# %%
imgs, label = val_ds[10]
plt.imshow(denormalize(imgs[10], mean, std))

# %%
test_transformer = transforms.Compose([
                        transforms.Resize((h, w)),
                        transforms.ToTensor(),
                        transforms.Normalize(mean, std)
                        ])

test_ds = VideoDataset(imgs_path=test_X, labels=test_Y, n_frames=n_frames, transform=test_transformer)
len(test_ds)
# Out:
# 1638

# %%
imgs, label = test_ds[10]
plt.imshow(denormalize(imgs[10], mean, std))

# %% [markdown]
# ## *Create training, validation, testing dataloaders*

# %%
def collate_fn_r3d_18(batch):
    imgs_batch, label_batch = list(zip(*batch))
    imgs_batch = [imgs for imgs in imgs_batch if len(imgs)>0]
    label_batch = [torch.tensor(l) for l, imgs in zip(label_batch, imgs_batch) if len(imgs)>0]
    imgs_tensor = torch.stack(imgs_batch)
    imgs_tensor = torch.transpose(imgs_tensor, 2, 1)
    labels_tensor = torch.stack(label_batch)
    return imgs_tensor, labels_tensor

def collate_fn_rnn(batch):
    imgs_batch, label_batch = list(zip(*batch))
    imgs_batch = [imgs for imgs in imgs_batch if len(imgs)>0]
    label_batch = [torch.tensor(l) for l, imgs in zip(label_batch, imgs_batch) if len(imgs)>0]
    imgs_tensor = torch.stack(imgs_batch)
    labels_tensor = torch.stack(label_batch)
    return imgs_tensor,labels_tensor

batch_size = 1
if model_type == "rnn":
    train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, collate_fn=collate_fn_rnn)
    val_dl = DataLoader(val_ds, batch_size=batch_size, shuffle=False, collate_fn=collate_fn_rnn)
    test_dl = DataLoader(test_ds, batch_size=batch_size, shuffle=False, collate_fn=collate_fn_rnn)
else:
    train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, collate_fn=collate_fn_r3d_18)
    val_dl = DataLoader(val_ds, batch_size=batch_size, shuffle=False, collate_fn=collate_fn_r3d_18)
    test_dl = DataLoader(test_ds, batch_size=batch_size, shuffle=False, collate_fn=collate_fn_r3d_18)

# %%
for xb, yb in train_dl:
    print(xb.shape, yb.shape, yb[0])
    break

for xb, yb in val_dl:
    print(xb.shape, yb.shape, yb[0])
    break

for xb, yb in test_dl:
    print(xb.shape, yb.shape, yb[0])
    break
# Out:
# torch.Size([1, 3, 17, 128, 128]) torch.Size([1]) tensor(10)
# torch.Size([1, 3, 21, 128, 128]) torch.Size([1]) tensor(0)
# torch.Size([1, 3, 21, 128, 128]) torch.Size([1]) tensor(0)

# %% [markdown]
# ## *Create A New Model*

# %%
import torch.nn as nn
from collections import OrderedDict

model = r2plus1d_18(pretrained=True, n_classes=500)
checkpoint = torch.load("./pretrained/main_weights.pth")
new_state_dict = OrderedDict()
for k, v in checkpoint.items():
    name = k[7:]
    new_state_dict[name] = v
model.load_state_dict(new_state_dict)
model.fc1 = nn.Linear(model.fc1.in_features, n_classes)
model
# Out:
# r2plus1d_18(
#   (r2plus1d_18): Sequential(
#     (0): R2Plus1dStem(
#       (0): Conv3d(3, 45, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#       (1): BatchNorm3d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#       (3): Conv3d(45, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): BasicBlock(
#         (conv1): Sequential(
#           (0): Conv2Plus1D(
#             (0): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (1): BatchNorm3d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#             (3): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
# ...

# %%
with torch.no_grad():
    x = torch.zeros(1, 3, 15, h, w)
    y = model(x)
    print(y.shape)
# Out:
# torch.Size([1, 100])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
path_to_weights = "./weights/initial_weights.pt"
torch.save(model.state_dict(), path_to_weights)

# %% [markdown]
# ## *Model Training*

# %% [markdown]
# ### 1. *New Training Process*

# %%
from torch import optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

from utils.rgb_frames.train_val import train_val, loss_epoch


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
loss_fn = nn.CrossEntropyLoss(reduction="sum")
opt = optim.Adam(model.parameters(), lr=3e-5)
lr_scheduler = ReduceLROnPlateau(opt, mode="min", factor=0.5, patience=5, verbose=1)
# os.makedirs(".\models", exist_ok=True)

params_train = {
    "model": model,
    "loss_func": loss_fn,
    "opt": opt, 
    "train_dl": train_dl,
    "val_dl": val_dl,
    "lr_scheduler": lr_scheduler,
    "start_epoch": 0,
    "end_epoch": 100,
    "path_to_weights": "weights/weights_" + model_type + "_c" + str(n_classes) + "_v" + str(WEIGHTS_V) + ".tar",
    "path_to_checkpoint": "weights/checkpoint_" + model_type + "_c" + str(n_classes) + "_v" + str(WEIGHTS_V) + ".tar",
    "device": device
}

# %% [markdown]
# ### 2. *Complete Previous Training Process*

# %%
import torch
from torch import optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

from utils.rgb_frames.train_val import train_val, loss_epoch


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = r2plus1d_18(pretrained=False, n_classes=n_classes)
model = model.to(device)
loss_fn = nn.CrossEntropyLoss(reduction="sum")
opt = optim.Adam(model.parameters(), lr=3e-5)
lr_scheduler = ReduceLROnPlateau(opt, mode="min", factor=0.5, patience=5, verbose=1)


checkpoint = torch.load("./weights/checkpoint_3dcnn_c100_v40.tar")
checkpoint.keys()
# Out:
# dict_keys(['epochs', 'last_epoch', 'model_state_dict', 'optimizer_state_dict', 'scheduler', 'loss', 'hist'])

# %%
model.load_state_dict(checkpoint["model_state_dict"])
opt.load_state_dict(checkpoint["optimizer_state_dict"])
lr_scheduler.load_state_dict(checkpoint["scheduler"])
loss_fn.load_state_dict(checkpoint["loss"])
loss_history = checkpoint["hist"]["loss"]
metric_history = checkpoint["hist"]["metric"]
last_epoch = checkpoint["last_epoch"]
print(last_epoch)

# %%
# model, loss_func, opt, train_dl, val_dl, lr_scheduler, start_epoch, end_epoch, path_to_weights, path_to_checkpoint, device, loss_history=None, metric_history=None

params_train = {
    "model": model,
    "loss_func": loss_fn,
    "opt": opt, 
    "train_dl": train_dl,
    "val_dl": val_dl,
    "lr_scheduler": lr_scheduler,
    "start_epoch": last_epoch+1,
    "end_epoch": 6,
    "path_to_weights": "./weights/weights_" + model_type + "_c" + str(n_classes) + "_v" + str(WEIGHTS_V) + ".tar",
    "path_to_checkpoint": "./weights/checkpoint_" + model_type + "_c" + str(n_classes) + "_v" + str(WEIGHTS_V) + ".tar",
    "device": device,
    "loss_history": loss_history,
    "metric_history": metric_history
}

# %% [markdown]
# ### Train the model

# %%
# !nvidia-smi
# Out:
# Wed Dec 29 14:24:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 471.41       Driver Version: 471.41       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   55C    P0    14W /  N/A |   1457MiB /  4096MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
WEIGHTS_V += 1
model, loss_hist, metric_hist = train_val(**params_train)
# Out:
# Epoch 0/99, current lr=3e-05
# Training
# 100%|██████████| 12359/12359 [2:02:34<00:00,  1.68it/s]
# Validation
# 100%|██████████| 1931/1931 [07:40<00:00,  4.19it/s]
# Copied best model weights!
# train loss: 4.447663, train_accuracy: 2.33, val_loss: 4.676683, val_accuracy: 0.83
# Checkpoint saved
# ----------
# Epoch 1/99, current lr=3e-05
# Training
# 100%|██████████| 12359/12359 [1:48:17<00:00,  1.90it/s]
# Validation
# 100%|██████████| 1931/1931 [06:43<00:00,  4.78it/s]
# train loss: 3.804350, train_accuracy: 6.13, val_loss: 4.766686, val_accuracy: 0.93
# Checkpoint saved
# ----------
# Epoch 2/99, current lr=3e-05
# Training
# 100%|██████████| 12359/12359 [1:48:03<00:00,  1.91it/s]
# Validation
# 100%|██████████| 1931/1931 [06:50<00:00,  4.71it/s]
# train loss: 3.358551, train_accuracy: 11.32, val_loss: 4.729813, val_accuracy: 1.19
# Checkpoint saved
# ----------
# Epoch 3/99, current lr=3e-05
# Training
# 100%|██████████| 12359/12359 [1:47:16<00:00,  1.92it/s]
# Validation
# ...

# %%
plot_loss(loss_hist, metric_hist)

# %%
from utils.rgb_frames.train_val import plot_loss

plot_loss(loss_hist, metric_hist)

# %% [markdown]
# # *Model Testing*

# %% [markdown]
# #### 1. *Load pretrained weights*

# %%
import torch

import torch.nn as nn
from collections import OrderedDict

m = r2plus1d_18(pretrained=False, n_classes=3)
w = torch.load("./weights_3dcnn_v24.pt")
m.load_state_dict(w)
# Out:
# <All keys matched successfully>

# %%
loss_fn = nn.CrossEntropyLoss(reduction="sum")

params_test = {
    "model": model,
    "loss_func": loss_fn,
    "dataset_dl": test_dl,
    "device": device
}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.eval()
with torch.no_grad():
    
    testing_loss, testing_metric = loss_epoch(**params_test)

print("dev loss: %.6f, accuracy: %.2f" %(testing_loss,100*testing_metric))
# Out:
# 100%|██████████| 32/32 [00:04<00:00,  6.84it/s]
# dev loss: 0.063014, accuracy: 100.00
